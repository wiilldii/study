# %% [markdown]
# ### Задача 3. (Учебник 9.1)
#
# Екатерина изучает, какие пирожные представлены в кофейнях района, в котором она живет. Помогите Екатерине добавить информацию в новый файл.
#
# __ФОРМАТ ВВОДА__
#
# * Структурированный файл cakes.csv, в котором через точку с запятой записана информация о пирожных, их цене, кофейне и индикатор наличия глютена (1 — если пирожное с глютеном и 0 — если без).
# * Каждая строка имеет вид: <название пирожного>;<цена>;<название кофейни>;<индикатор наличия глютена>. Например, "Павлова;200;Шоколадница;1".
# * Гарантируется, что в названиях пирожных и кофеен нет ";" (точки с запятой).
# * В каждой строке записана информация только об одном пирожном.
# * Далее через пробел считывается информация о новом пирожном.
#
# __ФОРМАТ ВЫВОДА__
# * Новый файл cakes_new.csv, куда в была добавлена информация о пирожных из файла, а также информация о новом пирожном (через точку с запятой).
#
# __Ввод__
#
# `Чизкейк 290 Фокина 1`
#
# __ответ для 4.csv__
#
# ```
# FILE:
# Павлова;200;Шоколадница;1
# Павлова;250;Булочная1;1
# Наполеон;350;Шоколадница;1
# Павлова;210;КофеХауз;1
# Наполеон;200;ШоколадницаNew;1
# Трубочка с кремом;370;Булочная1;0
# Трубочка с кремом;340;Шоколадница;1
# Чизкейк;290;Фокина;1
# ```

# %%
# !cat cakes.csv
# Out:
# Павлова;200;Шоколадница;1
# Павлова;250;Булочная1;1
# Наполеон;350;Шоколадница;1
# Павлова;210;КофеХауз;1
# Наполеон;200;ШоколадницаNew;1
# Трубочка с кремом;370;Булочная1;0
# Трубочка с кремом;340;Шоколадница;1

# %% [markdown]
# ### Задача 2. (сем. 9)
#
# Вася готовится к контрольной работе по политологии и по мере прочтения материала помечает непонятные слова знаком * . "Звездочку" студент ставит в конце каждого непонятого им слова.
#
# Помогите Васе собрать все непонятные слова и подсчитайте, сколько раз каждое слово, символов в котором больше или равно семи, он пометил "звездочкой". Будем считать, что слова в тексте разделены пробелами.
#
# __ФОРМАТ ВВОДА__
#
# * Текстовый файл 2.txt , в котором записан конспект Васи с пометками. Непонятым считается любое слово, заканчивающееся знаком '*'.   Между словом и * точно не стоят пробелы.
#
# __ФОРМАТ ВЫВОДА__
#
# * Словарь, где ключи — непонятные Васе слова, количество символов в которых больше или равно семи, (уже без знака * на конце), а значения — целые числа, сколько раз каждое слово отметил Вася. Слова должны быть добавлены в словарь в том же порядке, в каком они встречались в оригинальном файле.
# * На следующей строке напечатайте первое по алфавиту слово из вашего словаря.
#
# __ответ для 2.txt__
#
# `{'political': 5, 'regimes': 2, 'monarchy': 1}`
#
# `monarchy`

# %% [markdown]
# ### Задача 4. (сем. 10)
#
# Для сдачи курса по дизайну студентам необходимо сдать дизайн 10 постеров. Сотрудник учебного офиса ведет учет, записывая в специальную систему фамилии студентов и количество сданных постеров.
#
# Напишите функцию, которая выводит фамилии студентов, которым осталось сдать не более 2 работ.
#
# __ТРЕБУЕМАЯ ФУНКЦИЯ__
#
# * Функция posters_students принимает на вход два списка:
#     * в первом списке содержатся фамилии студентов (строки);
#     * во втором — соответствующее количество сданных ими постеров (целые числа).
# * Функция должна возвращать список фамилий студентов, которым осталось сдать не более двух работ (т.е. которые уже сдали 8 работ или более).
# * Фамилии студентов должны идти в том же порядке, что и в оригинальном списке.
# * При отсутствии таких студентов функция возвращает пустой список.
#
# __пример ввода__
#
# `['Алексеева', 'Андреева', 'Михайлов', 'Петров', 'Красильникова'], [13, 7, 13, 9, 8]`
#
# __пример вывода__
#
# `['Алексеева', 'Михайлов', 'Петров', 'Красильникова']`

# %% [markdown]
# ### Задача 3. (сем. 10)
#
# Витя записывает данные о своих друзьях в каждой стране. Напишите функцию, которая определяет, в скольки странах проживают люди с именем, которое интересует Витю.
#
# __ТРЕБУЕМАЯ ФУНКЦИЯ__
#
# * Функция get_contact, параметрами которой являются:
#     * словарь, где ключи — названия стран (строки), а значения — списки с именам друзей Вити из этих стран (списки строк).
#     * имя человека (строка), для которого нужно проверить, из какой он страны.
# * Функция должна возвращать количество стран, в которых живут знакомые Вити с указанным именем.
# * Если таких стран нет, то функция возвращает 0.
#
#
# __пример ввода__
#
# ```
# {
# 'UK': ['Alice', 'Alex', 'Rita'],
# 'Austria': ['Ann', 'Sia', 'Alex', 'Rick'],
# 'Germany': ['Nikita', 'Alice', 'Rob', 'Ann'],
# 'USA': ['Liza', 'Margo', 'Ann', 'Alex'],
# 'Russia': ['Rita', 'Ann', 'Liza', 'Ann']
# }, 'Ann'
# ```
#
# __пример вывода__
#
# `4`

# %%
get_contact({
'UK': ['Alice', 'Alex', 'Rita'],
'Austria': ['Ann', 'Sia', 'Alex', 'Rick'],
'Germany': ['Nikita', 'Alice', 'Rob', 'Ann'],
'USA': ['Liza', 'Margo', 'Ann', 'Alex'],
'Russia': ['Rita', 'Ann', 'Liza', 'Ann']
}, 'Ann')
# Out:
# 4

# %% [markdown]
# ### Задача 4. (сем 9)
#
# Екатерина изучает, какие пирожные представлены в кофейнях района, в котором она живет. Помогите Екатерине собрать информацию о средних ценах на пирожные, которые представлены в ее районе, и определить самое дорогое пирожное.
#
# __ФОРМАТ ВВОДА__
#
# * Структурированный файл 4.csv, в котором через точку с запятой записана информация о пирожных, их цене, кофейне и индикатор наличия глютена (1 — если пирожное с глютеном и 0 — если без).
# * Каждая строка имеет вид: `<название пирожного>;<цена>;<название кофейни>;<индикатор наличия глютена>`. Например, `"Павлова;200;Шоколадница;1"`.
# * Гарантируется, что в названиях пирожных и кофеен нет ";" (точки с запятой).
# * В каждой строке записана информация только об одном пирожном.
#
# __ФОРМАТ ВЫВОДА__
# * Строка — название в среднем самого дорогого пирожного.
# * Гарантируется, что такое пирожное только одно.
#
# __ответ для 4.csv__
#
# `Трубочка с кремом`

# %% [markdown]
# ### Задача 10. (демоверсия КР)
#
# Вы работаете аналитиком в торговой сети и изучаете суммарную прибыль по каждой из категории товаров. Найдите товар, приносящий максимальную суммарную прибыль.
#
# __Формат ввода__
#
# * Записи о продаже товаров: название товара и, через запятую, полученная с этой продажи прибыль (целое число). Каждая запись вводится с новой строки. Название товара может содержать любые символы, кроме запятой.
# * Один товар могут продавать любое количество раз, но в каждой строке указывается информация только про одну продажу.
# * Когда записи заканчиваются, на отдельной строке вводится слово "END".
#
#
# __Формат вывода__
#
# * Название товара, который принес наибольшую суммарную прибыль и, через пробел, сумма этой прибыли.
# * Гарантируется, что такой товар только один.
#
#
# __пример ввода__
#
# ```
# Шоколад,1000
# Мармеладки,600
# Шоколад,6000
# Киндер-сюрприз,1000
# Мармеладки,300
# END
# ```
#
# __пример вывода__
#
# `Шоколад 7000`

# %% [markdown]
# ### Задача 5*. (сем. 10)
#
# Реализовать шифр Цезаря.
#
# Шифр Цезаря — это простой метод шифрования, в котором каждая буква открытого текста заменяется на букву, находящуюся на определенном расстоянии (сдвиг) от неё в алфавите. Например, при сдвиге 3, буква "А" была бы заменена на "Г", "Б" станет "Д", и так далее.
#
# Необходимо реализовать функцию, которая на вход получает через пробел зашифрованное слово и ключ (сдвиг по алфавиту), которым оно было зашифровано. Необходимо вывести расшифрованное слово.

# %% [markdown]
# ![Shift](https://consoleflare.com/blog/wp-content/uploads/2024/03/image-1-1024x480.png)

# %%
from string import ascii_letters

# %%
ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
